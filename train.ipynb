# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_selection import SelectKBest, f_classif
# Установка seed для воспроизводимости результатов
np.random.seed(1234)

# Создаем соединение с базой данных
engine = create_engine("postgresql://robot-startml-ro:pheiph0hahj1Vaif@postgres.lab.karpov.courses:6432/startml")

# Загрузка данных
user_data = pd.read_sql("SELECT * FROM public.user_data", con=engine)
post_text_df = pd.read_sql("SELECT * FROM public.post_text_df", con=engine)
feed_data = pd.read_sql("SELECT * FROM public.feed_data ORDER BY timestamp DESC LIMIT 500000", con=engine)

# %%
# Объединяем данные в один DataFrame
user_feed = pd.merge(feed_data, user_data, on='user_id', how='left')
all_data = pd.merge(user_feed, post_text_df, on='post_id', how='left')

def generate_new_target(target, action):
    if target == 1 or action == 'like':
        return 1
    else:
        return 0

all_data['target'] = all_data.apply(lambda row: generate_new_target(row['target'], row['action']), axis=1)

# Создаем признаки
all_data['timestamp'] = pd.to_datetime(all_data['timestamp'])
all_data['day_of_week'] = all_data['timestamp'].dt.dayofweek
all_data['hour'] = all_data['timestamp'].dt.hour
all_data['time_slot'] = all_data['day_of_week'].astype(str) + '_' + all_data['hour'].astype(str)

train = all_data.drop(['action', 'timestamp'], axis=1)

# %%
# Generate User Features
# Add user mean to train
user_means = train.groupby('user_id')['target'].mean()
train['user_means'] = train['user_id'].map(user_means)
# Target by'topic'
unique_topics = train['topic'].unique()
for topic in unique_topics:
    topic_col_name = f"{topic}_target"
    user_target_by_topic = train[train['target'] == 1].groupby(['user_id', 'topic']).size().reset_index(name='temp')
    user_target_by_topic = user_target_by_topic[user_target_by_topic['topic'] == topic].rename(columns={'temp': topic_col_name})
    user_target_by_topic = user_target_by_topic[['user_id', topic_col_name]]
    train = pd.merge(train, user_target_by_topic, on='user_id', how='left')
    train[topic_col_name].fillna(0, inplace=True)

# %%
# Расчет общего количества лайков для каждого поста
popularity = train.groupby('post_id')['target'].sum().reset_index()
popularity.columns = ['post_id', 'total_likes']
train = pd.merge(train, popularity, on='post_id', how='left')
train['total_likes'].fillna(0, inplace=True)
# Добавляем признак CTR (Click-Through Rate) для каждого поста
post_ctr = train.groupby('post_id')['target'].mean().reset_index()
post_ctr.columns = ['post_id', 'post_ctr']
train = pd.merge(train, post_ctr, on='post_id', how='left')

train = train.drop(['user_id', 'post_id', 'text', 'day_of_week', 'hour'], axis=1)

X_train = train.drop('target', axis=1)
y_train = train['target']

# %%
from catboost import CatBoostClassifier

catboost = CatBoostClassifier(random_seed=1, depth=6, learning_rate=0.1, iterations=500, eval_metric='AUC',
                              cat_features=['age', 'country', 'city', 'topic', 'exp_group', 'time_slot', 'source', 'os', 'gender'])

catboost.fit(X_train, y_train)
# Out:
# 0:	total: 519ms	remaining: 4m 18s
# 1:	total: 1.19s	remaining: 4m 56s
# 2:	total: 1.56s	remaining: 4m 18s
# 3:	total: 1.96s	remaining: 4m 3s
# 4:	total: 2.35s	remaining: 3m 52s
# 5:	total: 2.73s	remaining: 3m 44s
# 6:	total: 3.17s	remaining: 3m 43s
# 7:	total: 3.54s	remaining: 3m 37s
# 8:	total: 3.88s	remaining: 3m 31s
# 9:	total: 4.2s	remaining: 3m 25s
# 10:	total: 4.57s	remaining: 3m 23s
# 11:	total: 4.92s	remaining: 3m 20s
# 12:	total: 5.38s	remaining: 3m 21s
# 13:	total: 5.75s	remaining: 3m 19s
# 14:	total: 6.2s	remaining: 3m 20s
# 15:	total: 6.54s	remaining: 3m 17s
# 16:	total: 6.88s	remaining: 3m 15s
# 17:	total: 7.28s	remaining: 3m 14s
# 18:	total: 7.66s	remaining: 3m 13s
# 19:	total: 8.05s	remaining: 3m 13s
# 20:	total: 8.49s	remaining: 3m 13s
# 21:	total: 8.84s	remaining: 3m 12s
# 22:	total: 9.36s	remaining: 3m 14s
# 23:	total: 9.75s	remaining: 3m 13s
# 24:	total: 10.1s	remaining: 3m 12s
# 25:	total: 10.5s	remaining: 3m 11s
# 26:	total: 10.9s	remaining: 3m 10s
# 27:	total: 11.3s	remaining: 3m 9s
# 28:	total: 11.6s	remaining: 3m 7s
# 29:	total: 11.9s	remaining: 3m 6s
# 30:	total: 12.3s	remaining: 3m 5s
# 31:	total: 12.6s	remaining: 3m 3s
# 32:	total: 12.9s	remaining: 3m 1s
# 33:	total: 13.1s	remaining: 3m
# 34:	total: 13.5s	remaining: 2m 59s
# 35:	total: 13.8s	remaining: 2m 58s
# 36:	total: 14.2s	remaining: 2m 57s
# 37:	total: 14.5s	remaining: 2m 56s
# 38:	total: 14.8s	remaining: 2m 54s
# 39:	total: 15.1s	remaining: 2m 53s
# 40:	total: 15.4s	remaining: 2m 52s
# 41:	total: 15.7s	remaining: 2m 51s
# 42:	total: 16.1s	remaining: 2m 51s
# 43:	total: 16.5s	remaining: 2m 51s
# 44:	total: 16.8s	remaining: 2m 49s
# 45:	total: 17.2s	remaining: 2m 50s
# 46:	total: 17.7s	remaining: 2m 51s
# 47:	total: 18.2s	remaining: 2m 51s
# 48:	total: 18.6s	remaining: 2m 51s
# 49:	total: 19s	remaining: 2m 50s
# 50:	total: 19.3s	remaining: 2m 49s
# 51:	total: 19.7s	remaining: 2m 49s
# 52:	total: 20.2s	remaining: 2m 49s
# 53:	total: 20.7s	remaining: 2m 50s
# 54:	total: 21s	remaining: 2m 50s
# 55:	total: 21.3s	remaining: 2m 48s
# 56:	total: 21.6s	remaining: 2m 48s
# 57:	total: 22s	remaining: 2m 48s
# 58:	total: 22.4s	remaining: 2m 47s
# 59:	total: 22.9s	remaining: 2m 47s
# 60:	total: 23.3s	remaining: 2m 47s
# 61:	total: 23.7s	remaining: 2m 47s
# 62:	total: 24s	remaining: 2m 46s
# 63:	total: 24.4s	remaining: 2m 46s
# 64:	total: 24.8s	remaining: 2m 45s
# 65:	total: 25.2s	remaining: 2m 46s
# 66:	total: 25.6s	remaining: 2m 45s
# 67:	total: 26s	remaining: 2m 45s
# 68:	total: 26.4s	remaining: 2m 44s
# 69:	total: 26.8s	remaining: 2m 44s
# 70:	total: 27.2s	remaining: 2m 44s
# 71:	total: 27.6s	remaining: 2m 44s
# 72:	total: 28s	remaining: 2m 43s
# 73:	total: 28.4s	remaining: 2m 43s
# 74:	total: 28.7s	remaining: 2m 42s
# 75:	total: 29.2s	remaining: 2m 42s
# 76:	total: 29.6s	remaining: 2m 42s
# 77:	total: 30.1s	remaining: 2m 42s
# 78:	total: 30.5s	remaining: 2m 42s
# 79:	total: 31s	remaining: 2m 42s
# 80:	total: 31.3s	remaining: 2m 42s
# 81:	total: 31.7s	remaining: 2m 41s
# 82:	total: 32.1s	remaining: 2m 41s
# 83:	total: 32.6s	remaining: 2m 41s
# 84:	total: 33.1s	remaining: 2m 41s
# 85:	total: 33.4s	remaining: 2m 40s
# 86:	total: 33.8s	remaining: 2m 40s
# 87:	total: 34.3s	remaining: 2m 40s
# 88:	total: 34.8s	remaining: 2m 40s
# 89:	total: 35.2s	remaining: 2m 40s
# 90:	total: 35.7s	remaining: 2m 40s
# 91:	total: 36.1s	remaining: 2m 40s
# 92:	total: 36.6s	remaining: 2m 40s
# 93:	total: 37s	remaining: 2m 39s
# 94:	total: 37.3s	remaining: 2m 39s
# 95:	total: 37.7s	remaining: 2m 38s
# 96:	total: 38.1s	remaining: 2m 38s
# 97:	total: 38.5s	remaining: 2m 37s
# 98:	total: 38.9s	remaining: 2m 37s
# 99:	total: 39.2s	remaining: 2m 36s
# 100:	total: 39.6s	remaining: 2m 36s
# 101:	total: 40s	remaining: 2m 35s
# 102:	total: 40.3s	remaining: 2m 35s
# 103:	total: 40.6s	remaining: 2m 34s
# 104:	total: 41s	remaining: 2m 34s
# 105:	total: 41.7s	remaining: 2m 34s
# 106:	total: 42.1s	remaining: 2m 34s
# 107:	total: 42.5s	remaining: 2m 34s
# 108:	total: 42.9s	remaining: 2m 33s
# 109:	total: 43.3s	remaining: 2m 33s
# 110:	total: 43.6s	remaining: 2m 32s
# 111:	total: 44.1s	remaining: 2m 32s
# 112:	total: 44.6s	remaining: 2m 32s
# 113:	total: 45.1s	remaining: 2m 32s
# 114:	total: 45.5s	remaining: 2m 32s
# 115:	total: 45.9s	remaining: 2m 31s
# 116:	total: 46.3s	remaining: 2m 31s
# 117:	total: 46.7s	remaining: 2m 31s
# 118:	total: 47s	remaining: 2m 30s
# 119:	total: 47.3s	remaining: 2m 29s
# 120:	total: 47.6s	remaining: 2m 29s
# 121:	total: 48s	remaining: 2m 28s
# 122:	total: 48.3s	remaining: 2m 28s
# 123:	total: 48.7s	remaining: 2m 27s
# 124:	total: 49s	remaining: 2m 27s
# 125:	total: 49.5s	remaining: 2m 26s
# 126:	total: 49.8s	remaining: 2m 26s
# 127:	total: 50.1s	remaining: 2m 25s
# 128:	total: 50.4s	remaining: 2m 25s
# 129:	total: 50.8s	remaining: 2m 24s
# 130:	total: 51.1s	remaining: 2m 24s
# 131:	total: 51.5s	remaining: 2m 23s
# 132:	total: 52s	remaining: 2m 23s
# 133:	total: 52.3s	remaining: 2m 22s
# 134:	total: 52.5s	remaining: 2m 22s
# 135:	total: 52.9s	remaining: 2m 21s
# 136:	total: 53.3s	remaining: 2m 21s
# 137:	total: 53.9s	remaining: 2m 21s
# 138:	total: 54.3s	remaining: 2m 20s
# 139:	total: 54.6s	remaining: 2m 20s
# 140:	total: 55s	remaining: 2m 19s
# 141:	total: 55.4s	remaining: 2m 19s
# 142:	total: 55.7s	remaining: 2m 19s
# 143:	total: 56.1s	remaining: 2m 18s
# 144:	total: 56.5s	remaining: 2m 18s
# 145:	total: 56.8s	remaining: 2m 17s
# 146:	total: 57.2s	remaining: 2m 17s
# 147:	total: 57.6s	remaining: 2m 16s
# 148:	total: 57.9s	remaining: 2m 16s
# 149:	total: 58.3s	remaining: 2m 15s
# 150:	total: 58.6s	remaining: 2m 15s
# 151:	total: 59s	remaining: 2m 15s
# 152:	total: 59.3s	remaining: 2m 14s
# 153:	total: 59.7s	remaining: 2m 14s
# 154:	total: 1m	remaining: 2m 14s
# 155:	total: 1m	remaining: 2m 13s
# 156:	total: 1m 1s	remaining: 2m 13s
# 157:	total: 1m 1s	remaining: 2m 13s
# 158:	total: 1m 1s	remaining: 2m 12s
# 159:	total: 1m 2s	remaining: 2m 12s
# 160:	total: 1m 2s	remaining: 2m 11s
# 161:	total: 1m 2s	remaining: 2m 11s
# 162:	total: 1m 3s	remaining: 2m 11s
# 163:	total: 1m 3s	remaining: 2m 10s
# 164:	total: 1m 4s	remaining: 2m 10s
# 165:	total: 1m 4s	remaining: 2m 9s
# 166:	total: 1m 4s	remaining: 2m 8s
# 167:	total: 1m 5s	remaining: 2m 8s
# 168:	total: 1m 5s	remaining: 2m 8s
# 169:	total: 1m 5s	remaining: 2m 7s
# 170:	total: 1m 6s	remaining: 2m 7s
# 171:	total: 1m 6s	remaining: 2m 6s
# 172:	total: 1m 6s	remaining: 2m 6s
# 173:	total: 1m 7s	remaining: 2m 5s
# 174:	total: 1m 7s	remaining: 2m 5s
# 175:	total: 1m 7s	remaining: 2m 4s
# 176:	total: 1m 8s	remaining: 2m 4s
# 177:	total: 1m 8s	remaining: 2m 4s
# 178:	total: 1m 9s	remaining: 2m 3s
# 179:	total: 1m 9s	remaining: 2m 3s
# 180:	total: 1m 9s	remaining: 2m 2s
# 181:	total: 1m 10s	remaining: 2m 2s
# 182:	total: 1m 10s	remaining: 2m 1s
# 183:	total: 1m 10s	remaining: 2m 1s
# 184:	total: 1m 11s	remaining: 2m 1s
# 185:	total: 1m 11s	remaining: 2m
# 186:	total: 1m 11s	remaining: 2m
# 187:	total: 1m 12s	remaining: 1m 59s
# 188:	total: 1m 12s	remaining: 1m 59s
# 189:	total: 1m 12s	remaining: 1m 58s
# 190:	total: 1m 13s	remaining: 1m 58s
# 191:	total: 1m 13s	remaining: 1m 58s
# 192:	total: 1m 13s	remaining: 1m 57s
# 193:	total: 1m 14s	remaining: 1m 57s
# 194:	total: 1m 14s	remaining: 1m 56s
# 195:	total: 1m 15s	remaining: 1m 56s
# 196:	total: 1m 15s	remaining: 1m 56s
# 197:	total: 1m 15s	remaining: 1m 55s
# 198:	total: 1m 16s	remaining: 1m 55s
# 199:	total: 1m 16s	remaining: 1m 54s
# 200:	total: 1m 17s	remaining: 1m 54s
# 201:	total: 1m 17s	remaining: 1m 54s
# 202:	total: 1m 17s	remaining: 1m 53s
# 203:	total: 1m 18s	remaining: 1m 53s
# 204:	total: 1m 18s	remaining: 1m 52s
# 205:	total: 1m 18s	remaining: 1m 52s
# 206:	total: 1m 19s	remaining: 1m 51s
# 207:	total: 1m 19s	remaining: 1m 51s
# 208:	total: 1m 19s	remaining: 1m 50s
# 209:	total: 1m 20s	remaining: 1m 50s
# 210:	total: 1m 20s	remaining: 1m 50s
# 211:	total: 1m 20s	remaining: 1m 49s
# 212:	total: 1m 21s	remaining: 1m 49s
# 213:	total: 1m 21s	remaining: 1m 48s
# 214:	total: 1m 21s	remaining: 1m 48s
# 215:	total: 1m 22s	remaining: 1m 48s
# 216:	total: 1m 22s	remaining: 1m 47s
# 217:	total: 1m 22s	remaining: 1m 47s
# 218:	total: 1m 23s	remaining: 1m 46s
# 219:	total: 1m 23s	remaining: 1m 46s
# 220:	total: 1m 23s	remaining: 1m 45s
# 221:	total: 1m 24s	remaining: 1m 45s
# 222:	total: 1m 24s	remaining: 1m 45s
# 223:	total: 1m 24s	remaining: 1m 44s
# 224:	total: 1m 25s	remaining: 1m 44s
# 225:	total: 1m 25s	remaining: 1m 43s
# 226:	total: 1m 26s	remaining: 1m 43s
# 227:	total: 1m 26s	remaining: 1m 43s
# 228:	total: 1m 26s	remaining: 1m 42s
# 229:	total: 1m 27s	remaining: 1m 42s
# 230:	total: 1m 27s	remaining: 1m 42s
# 231:	total: 1m 28s	remaining: 1m 41s
# 232:	total: 1m 28s	remaining: 1m 41s
# 233:	total: 1m 28s	remaining: 1m 41s
# 234:	total: 1m 29s	remaining: 1m 40s
# 235:	total: 1m 29s	remaining: 1m 40s
# 236:	total: 1m 29s	remaining: 1m 39s
# 237:	total: 1m 30s	remaining: 1m 39s
# 238:	total: 1m 30s	remaining: 1m 38s
# 239:	total: 1m 30s	remaining: 1m 38s
# 240:	total: 1m 31s	remaining: 1m 38s
# 241:	total: 1m 31s	remaining: 1m 37s
# 242:	total: 1m 31s	remaining: 1m 37s
# 243:	total: 1m 32s	remaining: 1m 36s
# 244:	total: 1m 32s	remaining: 1m 36s
# 245:	total: 1m 32s	remaining: 1m 35s
# 246:	total: 1m 33s	remaining: 1m 35s
# 247:	total: 1m 33s	remaining: 1m 35s
# 248:	total: 1m 33s	remaining: 1m 34s
# 249:	total: 1m 34s	remaining: 1m 34s
# 250:	total: 1m 34s	remaining: 1m 33s
# 251:	total: 1m 35s	remaining: 1m 33s
# 252:	total: 1m 35s	remaining: 1m 33s
# 253:	total: 1m 35s	remaining: 1m 32s
# 254:	total: 1m 36s	remaining: 1m 32s
# 255:	total: 1m 36s	remaining: 1m 31s
# 256:	total: 1m 36s	remaining: 1m 31s
# 257:	total: 1m 37s	remaining: 1m 31s
# 258:	total: 1m 37s	remaining: 1m 30s
# 259:	total: 1m 37s	remaining: 1m 30s
# 260:	total: 1m 38s	remaining: 1m 30s
# 261:	total: 1m 38s	remaining: 1m 29s
# 262:	total: 1m 38s	remaining: 1m 29s
# 263:	total: 1m 39s	remaining: 1m 28s
# 264:	total: 1m 39s	remaining: 1m 28s
# 265:	total: 1m 40s	remaining: 1m 28s
# 266:	total: 1m 40s	remaining: 1m 27s
# 267:	total: 1m 40s	remaining: 1m 27s
# 268:	total: 1m 41s	remaining: 1m 26s
# 269:	total: 1m 41s	remaining: 1m 26s
# 270:	total: 1m 41s	remaining: 1m 26s
# 271:	total: 1m 42s	remaining: 1m 25s
# 272:	total: 1m 42s	remaining: 1m 25s
# 273:	total: 1m 42s	remaining: 1m 24s
# 274:	total: 1m 43s	remaining: 1m 24s
# 275:	total: 1m 43s	remaining: 1m 24s
# 276:	total: 1m 43s	remaining: 1m 23s
# 277:	total: 1m 44s	remaining: 1m 23s
# 278:	total: 1m 44s	remaining: 1m 22s
# 279:	total: 1m 45s	remaining: 1m 22s
# 280:	total: 1m 45s	remaining: 1m 22s
# 281:	total: 1m 45s	remaining: 1m 21s
# 282:	total: 1m 46s	remaining: 1m 21s
# 283:	total: 1m 46s	remaining: 1m 20s
# 284:	total: 1m 46s	remaining: 1m 20s
# 285:	total: 1m 47s	remaining: 1m 20s
# 286:	total: 1m 47s	remaining: 1m 19s
# 287:	total: 1m 47s	remaining: 1m 19s
# 288:	total: 1m 48s	remaining: 1m 18s
# 289:	total: 1m 48s	remaining: 1m 18s
# 290:	total: 1m 48s	remaining: 1m 18s
# 291:	total: 1m 49s	remaining: 1m 17s
# 292:	total: 1m 49s	remaining: 1m 17s
# 293:	total: 1m 49s	remaining: 1m 16s
# 294:	total: 1m 50s	remaining: 1m 16s
# 295:	total: 1m 50s	remaining: 1m 16s
# 296:	total: 1m 50s	remaining: 1m 15s
# 297:	total: 1m 51s	remaining: 1m 15s
# 298:	total: 1m 51s	remaining: 1m 14s
# 299:	total: 1m 51s	remaining: 1m 14s
# 300:	total: 1m 52s	remaining: 1m 14s
# 301:	total: 1m 52s	remaining: 1m 13s
# 302:	total: 1m 52s	remaining: 1m 13s
# 303:	total: 1m 53s	remaining: 1m 12s
# 304:	total: 1m 53s	remaining: 1m 12s
# 305:	total: 1m 53s	remaining: 1m 12s
# 306:	total: 1m 54s	remaining: 1m 11s
# 307:	total: 1m 54s	remaining: 1m 11s
# 308:	total: 1m 55s	remaining: 1m 11s
# 309:	total: 1m 55s	remaining: 1m 10s
# 310:	total: 1m 55s	remaining: 1m 10s
# 311:	total: 1m 56s	remaining: 1m 10s
# 312:	total: 1m 56s	remaining: 1m 9s
# 313:	total: 1m 56s	remaining: 1m 9s
# 314:	total: 1m 57s	remaining: 1m 8s
# 315:	total: 1m 57s	remaining: 1m 8s
# 316:	total: 1m 58s	remaining: 1m 8s
# 317:	total: 1m 58s	remaining: 1m 7s
# 318:	total: 1m 58s	remaining: 1m 7s
# 319:	total: 1m 59s	remaining: 1m 7s
# 320:	total: 1m 59s	remaining: 1m 6s
# 321:	total: 1m 59s	remaining: 1m 6s
# 322:	total: 2m	remaining: 1m 5s
# 323:	total: 2m	remaining: 1m 5s
# 324:	total: 2m 1s	remaining: 1m 5s
# 325:	total: 2m 1s	remaining: 1m 4s
# 326:	total: 2m 1s	remaining: 1m 4s
# 327:	total: 2m 2s	remaining: 1m 3s
# 328:	total: 2m 2s	remaining: 1m 3s
# 329:	total: 2m 2s	remaining: 1m 3s
# 330:	total: 2m 2s	remaining: 1m 2s
# 331:	total: 2m 3s	remaining: 1m 2s
# 332:	total: 2m 3s	remaining: 1m 2s
# 333:	total: 2m 4s	remaining: 1m 1s
# 334:	total: 2m 4s	remaining: 1m 1s
# 335:	total: 2m 4s	remaining: 1m
# 336:	total: 2m 5s	remaining: 1m
# 337:	total: 2m 5s	remaining: 1m
# 338:	total: 2m 5s	remaining: 59.8s
# 339:	total: 2m 6s	remaining: 59.4s
# 340:	total: 2m 6s	remaining: 59s
# 341:	total: 2m 7s	remaining: 58.7s
# 342:	total: 2m 7s	remaining: 58.3s
# 343:	total: 2m 7s	remaining: 57.9s
# 344:	total: 2m 8s	remaining: 57.6s
# 345:	total: 2m 8s	remaining: 57.2s
# 346:	total: 2m 8s	remaining: 56.8s
# 347:	total: 2m 9s	remaining: 56.4s
# 348:	total: 2m 9s	remaining: 56.1s
# 349:	total: 2m 10s	remaining: 55.7s
# 350:	total: 2m 10s	remaining: 55.3s
# 351:	total: 2m 10s	remaining: 54.9s
# 352:	total: 2m 10s	remaining: 54.5s
# 353:	total: 2m 11s	remaining: 54.2s
# 354:	total: 2m 11s	remaining: 53.8s
# 355:	total: 2m 12s	remaining: 53.4s
# 356:	total: 2m 12s	remaining: 53s
# 357:	total: 2m 12s	remaining: 52.6s
# 358:	total: 2m 13s	remaining: 52.3s
# 359:	total: 2m 13s	remaining: 51.9s
# 360:	total: 2m 13s	remaining: 51.5s
# 361:	total: 2m 14s	remaining: 51.1s
# 362:	total: 2m 14s	remaining: 50.7s
# 363:	total: 2m 14s	remaining: 50.4s
# 364:	total: 2m 15s	remaining: 50s
# 365:	total: 2m 15s	remaining: 49.6s
# 366:	total: 2m 15s	remaining: 49.2s
# 367:	total: 2m 16s	remaining: 48.9s
# 368:	total: 2m 16s	remaining: 48.5s
# 369:	total: 2m 17s	remaining: 48.1s
# 370:	total: 2m 17s	remaining: 47.8s
# 371:	total: 2m 17s	remaining: 47.4s
# 372:	total: 2m 18s	remaining: 47s
# 373:	total: 2m 18s	remaining: 46.7s
# 374:	total: 2m 19s	remaining: 46.3s
# 375:	total: 2m 19s	remaining: 46s
# 376:	total: 2m 19s	remaining: 45.6s
# 377:	total: 2m 20s	remaining: 45.3s
# 378:	total: 2m 20s	remaining: 44.9s
# 379:	total: 2m 20s	remaining: 44.5s
# 380:	total: 2m 21s	remaining: 44.1s
# 381:	total: 2m 21s	remaining: 43.8s
# 382:	total: 2m 22s	remaining: 43.4s
# 383:	total: 2m 22s	remaining: 43.1s
# 384:	total: 2m 22s	remaining: 42.7s
# 385:	total: 2m 23s	remaining: 42.3s
# 386:	total: 2m 23s	remaining: 41.9s
# 387:	total: 2m 23s	remaining: 41.6s
# 388:	total: 2m 24s	remaining: 41.2s
# 389:	total: 2m 24s	remaining: 40.8s
# 390:	total: 2m 25s	remaining: 40.4s
# 391:	total: 2m 25s	remaining: 40.1s
# 392:	total: 2m 25s	remaining: 39.7s
# 393:	total: 2m 26s	remaining: 39.3s
# 394:	total: 2m 26s	remaining: 38.9s
# 395:	total: 2m 26s	remaining: 38.6s
# 396:	total: 2m 27s	remaining: 38.2s
# 397:	total: 2m 27s	remaining: 37.8s
# 398:	total: 2m 27s	remaining: 37.4s
# 399:	total: 2m 28s	remaining: 37.1s
# 400:	total: 2m 28s	remaining: 36.7s
# 401:	total: 2m 28s	remaining: 36.3s
# 402:	total: 2m 29s	remaining: 35.9s
# 403:	total: 2m 29s	remaining: 35.6s
# 404:	total: 2m 30s	remaining: 35.2s
# 405:	total: 2m 30s	remaining: 34.8s
# 406:	total: 2m 30s	remaining: 34.5s
# 407:	total: 2m 31s	remaining: 34.1s
# 408:	total: 2m 31s	remaining: 33.7s
# 409:	total: 2m 31s	remaining: 33.3s
# 410:	total: 2m 32s	remaining: 33s
# 411:	total: 2m 32s	remaining: 32.6s
# 412:	total: 2m 32s	remaining: 32.2s
# 413:	total: 2m 33s	remaining: 31.8s
# 414:	total: 2m 33s	remaining: 31.4s
# 415:	total: 2m 33s	remaining: 31.1s
# 416:	total: 2m 34s	remaining: 30.7s
# 417:	total: 2m 34s	remaining: 30.3s
# 418:	total: 2m 34s	remaining: 29.9s
# 419:	total: 2m 35s	remaining: 29.6s
# 420:	total: 2m 35s	remaining: 29.2s
# 421:	total: 2m 36s	remaining: 28.8s
# 422:	total: 2m 36s	remaining: 28.5s
# 423:	total: 2m 36s	remaining: 28.1s
# 424:	total: 2m 37s	remaining: 27.7s
# 425:	total: 2m 37s	remaining: 27.4s
# 426:	total: 2m 37s	remaining: 27s
# 427:	total: 2m 38s	remaining: 26.6s
# 428:	total: 2m 38s	remaining: 26.2s
# 429:	total: 2m 38s	remaining: 25.9s
# 430:	total: 2m 39s	remaining: 25.5s
# 431:	total: 2m 39s	remaining: 25.1s
# 432:	total: 2m 40s	remaining: 24.8s
# 433:	total: 2m 40s	remaining: 24.4s
# 434:	total: 2m 40s	remaining: 24s
# 435:	total: 2m 41s	remaining: 23.6s
# 436:	total: 2m 41s	remaining: 23.3s
# 437:	total: 2m 41s	remaining: 22.9s
# 438:	total: 2m 42s	remaining: 22.5s
# 439:	total: 2m 42s	remaining: 22.2s
# 440:	total: 2m 42s	remaining: 21.8s
# 441:	total: 2m 43s	remaining: 21.4s
# 442:	total: 2m 43s	remaining: 21s
# 443:	total: 2m 43s	remaining: 20.7s
# 444:	total: 2m 44s	remaining: 20.3s
# 445:	total: 2m 44s	remaining: 19.9s
# 446:	total: 2m 45s	remaining: 19.6s
# 447:	total: 2m 45s	remaining: 19.2s
# 448:	total: 2m 45s	remaining: 18.8s
# 449:	total: 2m 46s	remaining: 18.5s
# 450:	total: 2m 46s	remaining: 18.1s
# 451:	total: 2m 46s	remaining: 17.7s
# 452:	total: 2m 47s	remaining: 17.4s
# 453:	total: 2m 47s	remaining: 17s
# 454:	total: 2m 47s	remaining: 16.6s
# 455:	total: 2m 48s	remaining: 16.2s
# 456:	total: 2m 48s	remaining: 15.9s
# 457:	total: 2m 48s	remaining: 15.5s
# 458:	total: 2m 49s	remaining: 15.1s
# 459:	total: 2m 49s	remaining: 14.8s
# 460:	total: 2m 50s	remaining: 14.4s
# 461:	total: 2m 50s	remaining: 14s
# 462:	total: 2m 50s	remaining: 13.7s
# 463:	total: 2m 51s	remaining: 13.3s
# 464:	total: 2m 51s	remaining: 12.9s
# 465:	total: 2m 52s	remaining: 12.6s
# 466:	total: 2m 52s	remaining: 12.2s
# 467:	total: 2m 52s	remaining: 11.8s
# 468:	total: 2m 53s	remaining: 11.4s
# 469:	total: 2m 53s	remaining: 11.1s
# 470:	total: 2m 53s	remaining: 10.7s
# 471:	total: 2m 54s	remaining: 10.3s
# 472:	total: 2m 54s	remaining: 9.97s
# 473:	total: 2m 54s	remaining: 9.6s
# 474:	total: 2m 55s	remaining: 9.22s
# 475:	total: 2m 55s	remaining: 8.85s
# 476:	total: 2m 55s	remaining: 8.48s
# 477:	total: 2m 56s	remaining: 8.11s
# 478:	total: 2m 56s	remaining: 7.75s
# 479:	total: 2m 57s	remaining: 7.38s
# 480:	total: 2m 57s	remaining: 7.01s
# 481:	total: 2m 57s	remaining: 6.64s
# 482:	total: 2m 58s	remaining: 6.28s
# 483:	total: 2m 58s	remaining: 5.91s
# 484:	total: 2m 59s	remaining: 5.54s
# 485:	total: 2m 59s	remaining: 5.17s
# 486:	total: 3m	remaining: 4.8s
# 487:	total: 3m	remaining: 4.43s
# 488:	total: 3m	remaining: 4.07s
# 489:	total: 3m 1s	remaining: 3.69s
# 490:	total: 3m 1s	remaining: 3.32s
# 491:	total: 3m 1s	remaining: 2.96s
# 492:	total: 3m 2s	remaining: 2.59s
# 493:	total: 3m 2s	remaining: 2.22s
# 494:	total: 3m 2s	remaining: 1.85s
# 495:	total: 3m 3s	remaining: 1.48s
# 496:	total: 3m 3s	remaining: 1.11s
# 497:	total: 3m 3s	remaining: 739ms
# 498:	total: 3m 4s	remaining: 369ms
# 499:	total: 3m 4s	remaining: 0us

# %%
probabs = catboost.predict_proba(X_train)[:, 1]

test_for_eval = X_train.copy()
test_for_eval['user_id'] = all_data['user_id']

test_for_eval['probabilities'] = probabs
test_for_eval['target'] = y_train

hits_at_5 = 0
hits_at_10 = 0

for user in test_for_eval['user_id'].unique():
    part = test_for_eval[test_for_eval['user_id'] == user]
    part = part.sort_values('probabilities', ascending=False)
    
    top_5 = part.head(5)
    top_10 = part.head(10)

    if (top_5['target'] == 1).any():
        hits_at_5 += 1
    if (top_10['target'] == 1).any():
        hits_at_10 += 1
        
hit_rate_at_5 = hits_at_5 / len(test_for_eval['user_id'].unique())
hit_rate_at_10 = hits_at_10 / len(test_for_eval['user_id'].unique())

print(f"HitRate@5: {hit_rate_at_5}")
print(f"HitRate@10: {hit_rate_at_10}")

catboost.save_model('catboost_model',
                           format="cbm")
# Out:
# HitRate@5: 0.9240366972477064
# HitRate@10: 0.9435529608006672
